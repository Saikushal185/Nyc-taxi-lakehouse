# %% [markdown]
# # scratch notebook, attached to Serverless

# %%
print("spark:", spark.version)
display(spark.sql("SELECT current_catalog(), current_user()"))

# %% [markdown]
# # Delta is already there — nothing to install

# %%
spark.sql("CREATE TABLE IF NOT EXISTS workspace.default._smoke (id INT) USING DELTA")
spark.sql("INSERT INTO workspace.default._smoke VALUES (1)")
display(spark.sql("SELECT * FROM workspace.default._smoke"))
spark.sql("DROP TABLE workspace.default._smoke")

# %% [markdown]
# # and confirm the sample data you can start against immediately

# %%
display(spark.sql("SELECT * FROM samples.nyctaxi.trips LIMIT 5"))
